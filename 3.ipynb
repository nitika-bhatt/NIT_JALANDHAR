# %%
# Input decimal number
num = int(input("Enter a decimal number: "))

# Conversions using built-in functions
binary = bin(num)
octal = oct(num)
hexadecimal = hex(num)

# Display results
print("Binary equivalent:", binary)
print("Octal equivalent:", octal)
print("Hexadecimal equivalent:", hexadecimal)
# Out:
# Enter a decimal number: 23
# Binary equivalent: 0b10111
# Octal equivalent: 0o27
# Hexadecimal equivalent: 0x17

# %%
# Input string representing a floating-point number
num_str = input("Enter a floating-point number: ")

# Convert string to float
num = float(num_str)

# Add 10.5
result = num + 10.5

# Display result
print("Result after adding 10.5:", result)
# Out:
# Enter a floating-point number: 4.54
# Result after adding 10.5: 15.04
